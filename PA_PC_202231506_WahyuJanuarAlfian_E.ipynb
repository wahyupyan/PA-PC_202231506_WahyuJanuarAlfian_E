# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyupyan/PA-PC_202231506_WahyuJanuarAlfian_E/blob/main/PA_PC_202231506_WahyuJanuarAlfian_E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Fungsi untuk menampilkan gambar
def show_images(images, titles):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        plt.subplot(2, 3, i+1)
        plt.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
        plt.title(titles[i])
        plt.axis('off')
    plt.show()

# Baca gambar
image = cv2.imread('wahyu.jpg')

# 1. Citra Asli
original = image.copy()

# 2. Rotated
(h, w) = original.shape[:2]
center = (w // 2, h // 2)
matrix = cv2.getRotationMatrix2D(center, 30, 1.0)
rotated = cv2.warpAffine(original, matrix, (w, h))

# 3. Resized
resized = cv2.resize(original, (int(w * 0.2), int(h * 0.4)))

# 4. Cropped
cropped = original[int(h * 0.20):int(h * 0.80), int(w * 0.20):int(w * 0.80)]

# 5. Flipped
flipped = cv2.flip(original, 1)  # Horizontal flip

# 6. Translated
tx, ty = 100, 50  # Translation distances
translation_matrix = np.float32([[1, 0, tx], [0, 1, ty]])
translated = cv2.warpAffine(original, translation_matrix, (w, h))

# Tampilkan semua gambar
images = [original, rotated, resized, cropped, flipped, translated]
titles = ['Original', 'Rotated', 'Resized', 'Cropped', 'Flipped', 'Translated']
show_images(images, titles)
